# %%
import pandas as pd

# %% [markdown]
# ## Задание 1. Изменение и сохранение данных

# %% [markdown]
# ### 1. Считать данные из файла kc_house_data.csv с помощью pandas.

# %%
df= pd.read_csv('kc_house_data.csv', encoding = 'cp1251', sep=',')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2. Добавить новый признак price_per_sqft_living, который будет содержать среднюю стоимость за квадратный метр жилой площади (price / sqft_living).

# %%
df['price_per_sqft_living'] = df['price'] / df['sqft_living']
df.head()

# %% [markdown]
# ### 3. Создать новый признак age_of_house, который будет содержать возраст дома (текущий год минус год постройки yr_built).

# %%
current_year = pd.to_datetime('today').year
df['age_of_house'] = current_year - df['yr_built']
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
#
#    price_per_sqft_living  age_of_house
# 0             188.050847            70
# 1             209.338521            74
# 2             233.766234            92
# 3             308.163265            60
# 4             303.571429            38
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 4. Удалить признаки zipcode, lat, long и сохранить измененные данные в новый CSV файл modified_data.csv.

# %%
data_cleaned = df.drop(columns = ['zipcode', 'lat', 'long'])
data_cleaned.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  sqft_living15  sqft_lot15  \
# 0              0      1955             0           1340        5650
# 1            400      1951          1991           1690        7639
# 2              0      1933             0           2720        8062
# 3            910      1965             0           1360        5000
# 4              0      1987             0           1800        7503
#
#    price_per_sqft_living  age_of_house
# 0             188.050847            70
# 1             209.338521            74
# 2             233.766234            92
# 3             308.163265            60
# 4             303.571429            38

# %%
data_cleaned.to_csv('modified_kc_house_data.csv', index = False)

# %% [markdown]
# ## Задача 2. Интересные объекты недвижимости

# %% [markdown]
# ### 2. Найти дома с видом на набережную, стоимостью выше 500000 и более чем 2000 квадратных метров жилой площади.

# %%
client_house_1 = df[
    (df['waterfront'] > 0) &
    (df['price'] > 500000) &
    (df['sqft_living'] > 2000)
    ]

# %% [markdown]
# ### 3. Сохранить информацию о таких домах в новый CSV файл

# %%
client_house_1.to_csv('HW_3_client_house_1.csv', index = False)

# %% [markdown]
# ## Задача 3. Анализ жилых и общих площадей

# %% [markdown]
# ### 2. Построить DataFrame с колонками sqft_living, condition и price

# %%
client_house_2 = df[['sqft_living', 'condition', 'price']]
client_house_2.head()
# Out:
#    sqft_living  condition     price
# 0         1180          3  221900.0
# 1         2570          3  538000.0
# 2          770          3  180000.0
# 3         1960          5  604000.0
# 4         1680          3  510000.0

# %% [markdown]
# ### 3. Определить среднюю стоимость за квадратный метр жилой площади для разных состояний домов и сохраните в текстовый файл.

# %% [markdown]
# ### НЕ ПОЛУЧИЛОСЬ!

# %%
client_house_2['price_per_sqft_living'] = df['price'] / df['sqft_living']
client_house_2.head()
# Out:
# C:\Users\Hawk\AppData\Local\Temp\ipykernel_7580\4124164882.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   client_house_2['price_per_sqft_living'] = df['price'] / df['sqft_living']
#    sqft_living  condition     price  price_for_sqft_living  \
# 0         1180          3  221900.0             188.050847
# 1         2570          3  538000.0             209.338521
# 2          770          3  180000.0             233.766234
# 3         1960          5  604000.0             308.163265
# 4         1680          3  510000.0             303.571429
#
#    price_per_sqft_living
# 0             188.050847
# 1             209.338521
# 2             233.766234
# 3             308.163265
# 4             303.571429

# %% [markdown]
# ### Задача 4. Информация о клиентах и их покупках

# %% [markdown]
# ### 1. Создайте датафрейм с покупками и сохраните его в переменную purchases.

# %%
purchases = pd.DataFrame({
'purchase_id': [2001, 2002, 2003, 2004, 2005],
'client_id': [1001, 1002, 1003, 1001, 1005],
'house_id': [1234567890, 9876543210, 4567891230, 5566778899, 1122334455]
})
purchases.head()
# Out:
#    purchase_id  client_id    house_id
# 0         2001       1001  1234567890
# 1         2002       1002  9876543210
# 2         2003       1003  4567891230
# 3         2004       1001  5566778899
# 4         2005       1005  1122334455

# %% [markdown]
# ### 2. Создайте датафрейм с информацией о клиентах и сохраните его в переменную clients_info

# %%
clients_info = pd.DataFrame({
'client_id': [1001, 1002, 1003, 1004, 1005],
'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
'age': [30, 40, 35, 45, 50]
})
clients_info.head()
# Out:
#    client_id     name  age
# 0       1001    Alice   30
# 1       1002      Bob   40
# 2       1003  Charlie   35
# 3       1004    David   45
# 4       1005      Eve   50

# %% [markdown]
# ### 3. Присоедините информацию о клиентах к таблице purchases через метод join и сохраните в переменную purchases_with_info.

# %%
purchases_with_info = purchases.join(clients_info.set_index('client_id'), on = 'client_id')
purchases_with_info.head()
# Out:
#    purchase_id  client_id    house_id     name  age
# 0         2001       1001  1234567890    Alice   30
# 1         2002       1002  9876543210      Bob   40
# 2         2003       1003  4567891230  Charlie   35
# 3         2004       1001  5566778899    Alice   30
# 4         2005       1005  1122334455      Eve   50

# %% [markdown]
# ### 4. Присоедините информацию о клиентах к таблице purchases через метод merge и сохраните в переменную purchases_with_info_merged.

# %%
purchases_with_info_merged = pd.merge(purchases, clients_info, on = 'client_id')
purchases_with_info_merged.head()
# Out:
#    purchase_id  client_id    house_id     name  age
# 0         2001       1001  1234567890    Alice   30
# 1         2002       1002  9876543210      Bob   40
# 2         2003       1003  4567891230  Charlie   35
# 3         2004       1001  5566778899    Alice   30
# 4         2005       1005  1122334455      Eve   50

# %% [markdown]
# ### 5. Сохраните результаты в CSV файлы purchases_with_info.csv и purchases_with_info_merged.csv

# %%
purchases_with_info.to_csv('HW_3_purchases_with_info.csv', index=False)
purchases_with_info_merged.to_csv('HW_3_purchases_with_info_merged.csv', index=False)
